# %%
# hello world
print("hello world")
print('hello world')
# Out:
# hello world
# hello world

# %%
print("She said, 'hello world'")
print('She said, "hello world"')
print("She said, \"hello world\"")
# Out:
# She said, 'hello world'
# She said, "hello world"
# She said, "hello world"

# %%
# define some strings
first = 'beyonce'
last  = 'knowles'

# concatenate those strings
full = first + last

# print the strings
print(first)
print(last)
print(full)
print(first + last + "first")
print(first + ' ' + last + ' is the queen')
# Out:
# beyonce
# knowles
# beyonceknowles
# beyonceknowlesfirst
# beyonce knowles is the queen

# %%
# the long (but readable) way
name_length = len(full)
print(name_length)

# a more concise way to do it, functions within functions
print(len(full))
# Out:
# 14
# 14

# %%
# the long (but readble) way 
name_length= len(full)
print(name_length)

#a more concise way to do it, functions within functions 
print(len(full))
# Out:
# 14
# 14

# %%
#print strings and integers

print("there are" + str(name_length)+ "characters in Beyonce's name.")
print("There are", str(name_length), "characters in Beyonce's name")

# formatted print
print(f"There are {name_length} characters in Beyonce's name")
# Out:
# there are14characters in Beyonce's name.
# There are 14 characters in Beyonce's name
# There are 14 characters in Beyonce's name

# %%
x = 7
y = "7"

# putting just next to each other 
# print 77
print(str(x) + y)

# print 14
print(x + int(y))
# Out:
# 77
# 14

# %%
# methods to change the case of a string 
print(first, last)
print(first.upper())
print(last.lower())

# type() returns what type of variable something is 
print(type(first))

# make the namr properly cased (play with this string to make sure our algorithm is robust)
db_name = 'AndY'

# can give a literal string to capitalized
print(db_name.lower().capitalize()) 
      
# ultimately our alogorithm is: lowercase it first, then capitalize : should work on any string this way
db_name_lower = db_name.lower()
db_name_cap = db_name_lower.capitalize()
print(db_name_cap)

#here we do it all in one statment 
print(db_name.lower(). capitalize)
# Out:
# beyonce knowles
# BEYONCE
# knowles
# <class 'str'>
# Andy
# Andy
# <built-in method capitalize of str object at 0x1046873c0>

# %%
#problem 1 

 #1: Write a program that asks for the user's name and age, then prints a personalized greeting using string formatting (.format).

For Andy and 32, the output would be:

Hello, Andy! You are 32 years old.

# code here
name = input('Enter your name: ')
age  = input('Enter your age: ')

name = name.lower().capitalize()

print('Hello, {}. You are {} years old'.format(name, age))
print(f'Hello, {name}. You are {age} years old')

Hello, Andy. You are 32 years old
Hello, Andy. You are 32 years old

# %%
#problem 2

#2: Ask the user for a big number. If the user enters 1000000 (one million), the output will be:

This sure is a big number: 1,000,000

This sure is a big number: 1.000000e+06

big_num = input('Enter your big number here: ')

# show that the result from input() is always a string
# print(type(big_num))

print(f'This sure is a big number: {int(big_num):,d}')
print(f'This sure is a big number: {int(big_num):e}')

# %%
#problem 3

#Write a program that asks for the user's name and age, and then prints a personalized greeting using string formatting (.format).

For Andy and 32, output would be:

# %%
# problem 4 

bill = input('Enter the bill amount: ')
tip_percent = input('Enter the tip percentage: ')

bill = float(bill)
tip_percent = float(tip_percent)

tip_amount = bill * (tip_percent / 100)
total = bill + tip_amount

print(f'Bill: ${bill:.2f}')
print(f'Tip ({tip_percent}%): ${tip_amount:.2f}')
print('--------------------')
print(f'Total: ${total:.2f}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 6
#       3 bill = input ('42.75')
#       4 tip_percent=input('18')
# ----> 6 bill = float(bill)
#       7 tip_percent = float(tip_percent)
#       8 tip_amount = bill*(tip_percent/100)
#
# ValueError: could not convert string to float: ''
