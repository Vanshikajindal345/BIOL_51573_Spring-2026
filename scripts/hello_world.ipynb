# %% [markdown]
# # heading
# ## sub heading
# ### sub-sub heading
# #### sub-sub-sub heading
#
# bulleted list
#
# -micheal
# -tito
#
# numbered list:
#
# 1. first
# 1. second
# 1. third
# 1. fourth
#
# this is a code block 'python3 hello_world.py'

# %% [markdown]
# ### here is hello world in python

# %% [markdown]
# print ('hello world')
# print(7+9)
